# %%
include("example_Kmeans.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
include("example_Kmeans_Elbo.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# k = 1
# k = 2
# k = 3
# k = 4
# k = 5
# k = 6
# k = 7
# k = 8
# k = 9
# k = 10
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x16aa316a0>

# %%
include("example_Kmedian.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
minError
# Out:
# 32.44186609817892

# %%
include("example_Kmedians_Elbo.jl")
# Out:
# k = 1
# UndefVarError: kMedian not defined
#
# Stacktrace:
#  [1] top-level scope at /Users/zijiazhang/repos/CPSC340Assignments/A3/a3/example_Kmedians_Elbo.jl:15
#  [2] include at ./boot.jl:328 [inlined]
#  [3] include_relative(::Module, ::String) at ./loading.jl:1094
#  [4] include(::Module, ::String) at ./Base.jl:31
#  [5] include(::String) at ./client.jl:431
#  [6] top-level scope at In[19]:1
