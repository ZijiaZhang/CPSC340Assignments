# %%
include("example_RBF.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# With sigma = 0.000, validError = 37172.35
# With sigma = 0.000, validError = 37172.35
# With sigma = 0.000, validError = 37172.35
# With sigma = 0.000, validError = 37164.40
# With sigma = 0.000, validError = 36883.87
# With sigma = 0.001, validError = 36504.41
# With sigma = 0.002, validError = 36238.44
# With sigma = 0.004, validError = 34270.29
# With sigma = 0.008, validError = 31186.05
# With sigma = 0.016, validError = 26588.51
# With sigma = 0.031, validError = 23393.28
# With sigma = 0.063, validError = 690524.36
# With sigma = 0.125, validError = 22681564.47
# With sigma = 0.250, validError = 13448621.78
# With sigma = 0.500, validError = 36379.38
# With sigma = 1.000, validError = 247.77
# With sigma = 2.000, validError = 276.77
# With sigma = 4.000, validError = 641.21
# With sigma = 8.000, validError = 263.83
# With sigma = 16.000, validError = 241.33
# With sigma = 32.000, validError = 240.17
# ...

# %%
include("example_RBFRRR.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# With sigma = 0.000, validError = 37791.89
# With sigma = 0.000, validError = 37791.89
# With sigma = 0.000, validError = 37791.89
# With sigma = 0.000, validError = 37791.89
# With sigma = 0.000, validError = 37791.89
# With sigma = 0.001, validError = 37791.05
# With sigma = 0.002, validError = 37670.71
# With sigma = 0.004, validError = 36475.50
# With sigma = 0.008, validError = 33622.70
# With sigma = 0.016, validError = 28906.02
# With sigma = 0.031, validError = 38959.73
# With sigma = 0.063, validError = 246916.13
# With sigma = 0.125, validError = 85568.88
# With sigma = 0.250, validError = 73184.86
# With sigma = 0.500, validError = 7168.37
# With sigma = 1.000, validError = 88.98
# With sigma = 2.000, validError = 281.78
# With sigma = 4.000, validError = 265.42
# With sigma = 8.000, validError = 273.26
# With sigma = 16.000, validError = 281.03
# With sigma = 32.000, validError = 289.56
# ...
