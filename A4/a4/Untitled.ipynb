# %%
include("example_RBF.jl")
# Out:
# With sigma = 0.000, validError = 40162.79
# With sigma = 0.000, validError = 40162.79
# With sigma = 0.000, validError = 40162.79
# With sigma = 0.000, validError = 40154.84
# With sigma = 0.000, validError = 39874.03
# With sigma = 0.001, validError = 39478.31
# With sigma = 0.002, validError = 39317.66
# With sigma = 0.004, validError = 38193.22
# With sigma = 0.008, validError = 34821.05
# With sigma = 0.016, validError = 29662.76
# With sigma = 0.031, validError = 23089.77
# With sigma = 0.063, validError = 123899.18
# With sigma = 0.125, validError = 148221.58
# With sigma = 0.250, validError = 4076030.22
# With sigma = 0.500, validError = 134615.04
# With sigma = 1.000, validError = 125.06
# With sigma = 2.000, validError = 466.42
# With sigma = 4.000, validError = 550.43
# With sigma = 8.000, validError = 294.72
# With sigma = 16.000, validError = 272.83
# With sigma = 32.000, validError = 356.12
# With sigma = 64.000, validError = 265.07
# ...

# %%
include("example_RBFRRR.jl")
# Out:
# With sigma = 0
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# .000, validError = 38349.70
# With sigma = 0.000, validError = 38349.70
# With sigma = 0.000, validError = 38349.70
# With sigma = 0.000, validError = 38349.18
# With sigma = 0.000, validError = 38231.43
# With sigma = 0.001, validError = 37988.31
# With sigma = 0.002, validError = 37714.18
# With sigma = 0.004, validError = 36084.55
# With sigma = 0.008, validError = 33303.90
# With sigma = 0.016, validError = 28872.83
# With sigma = 0.031, validError = 23719.39
# With sigma = 0.063, validError = 22059.71
# With sigma = 0.125, validError = 71062.39
# With sigma = 0.250, validError = 151741.10
# With sigma = 0.500, validError = 2174.22
# With sigma = 1.000, validError = 82.47
# With sigma = 2.000, validError = 335.87
# With sigma = 4.000, validError = 354.70
# With sigma = 8.000, validError = 346.48
# With sigma = 16.000, validError = 351.56
# With sigma = 32.000, validError = 321.62
# ...

# %%
include("example_RBFCrossValidation.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# With best sigma of 1.000, testError = 259.86
# (-300, 400)

# %%
include("example_logistic.jl")
# Out:
# numberOfNonZero = 101
# trainError = 0.038
# validError = 0.106
# 0.106

# %%
include("example_logistic_loss.jl")
# Out:
# User and numerical derivatives agree
# Backtracking
# Backtracking
# Backtracking
# Backtracking
#      1     4.72491e-02     2.06433e+02     2.11866e+01
# User and numerical derivatives agree
#      2     3.92532e-02     5.75468e+01     1.00189e+01
# User and numerical derivatives agree
#      3     2.96095e-02     2.72500e+01     8.69643e+00
# User and numerical derivatives agree
#      4     2.43376e-02     1.92787e+01     4.09251e+00
# User and numerical derivatives agree
#      5     2.76717e-02     1.65306e+01     2.62678e+00
# User and numerical derivatives agree
#      6     7.27270e-02     1.48840e+01     2.19912e+00
# User and numerical derivatives agree
#      7     1.15654e-01     1.23718e+01     1.24129e+00
# User and numerical derivatives agree
#      8     8.35542e-02     1.06939e+01     1.02576e+00
# User and numerical derivatives agree
#      9     3.09735e-02     1.01964e+01     1.48468e+00
# User and numerical derivatives agree
# ...

# %%
include("example_logistic_loss_L2.jl")
# Out:
# User and numerical derivatives agree
# Backtracking
# Backtracking
# Backtracking
#      1     5.11540e-02     3.36073e+02     2.30538e+01
# User and numerical derivatives agree
#      2     4.19153e-02     1.53827e+02     1.03013e+01
# User and numerical derivatives agree
#      3     3.08338e-02     1.13033e+02     9.37973e+00
# User and numerical derivatives agree
#      4     2.43796e-02     1.00284e+02     5.65776e+00
# User and numerical derivatives agree
#      5     2.63624e-02     9.44993e+01     4.87980e+00
# User and numerical derivatives agree
#      6     7.07661e-02     9.00551e+01     4.64738e+00
# User and numerical derivatives agree
#      7     1.25564e-01     8.06443e+01     4.14572e+00
# User and numerical derivatives agree
#      8     9.49034e-02     6.94422e+01     3.31385e+00
# User and numerical derivatives agree
#      9     2.31279e-02     6.63664e+01     4.38126e+00
# User and numerical derivatives agree
# ...

# %%
include("example_logistic_loss_L1.jl")
# Out:
# Backtracking
# Backtracking
# Backtracking
# Backtracking
#      1     5.46005e-02     3.08091e+02     1.98874e+01
#      2     4.44279e-02     1.34750e+02     9.22229e+00
#      3     3.10187e-02     9.84273e+01     6.40694e+00
#      4     2.42450e-02     8.75290e+01     3.33180e+00
#      5     2.60015e-02     8.31329e+01     3.09902e+00
#      6     3.57106e-02     8.04767e+01     2.82503e+00
#      7     5.88215e-02     7.78638e+01     2.52986e+00
#      8     4.05515e-02     7.52168e+01     2.06632e+00
#      9     7.80515e-02     7.39547e+01     1.85904e+00
#     10     6.41057e-02     7.21922e+01     1.62509e+00
#     11     6.15968e-02     7.12183e+01     1.40552e+00
#     12     4.85198e-02     7.05091e+01     1.20689e+00
#     13     1.00602e-02     7.00373e+01     1.19645e+00
#     14     4.46677e-02     6.99499e+01     1.16988e+00
#     15     5.01303e-02     6.95911e+01     1.07521e+00
#     16     1.00000e+00     6.92269e+01     1.09792e+00
# Backtracking
# ...

# %%
include("example_logistic_loss_L0.jl")
# Out:
# minScore = 347.1734835449823
# minS = [1]
# Current set of selected variables (score = 347.173484):
# 1
# Current set of selected variables (score = 305.914385):
# 1 79
# Current set of selected variables (score = 277.768190):
# 1 37 79
# Current set of selected variables (score = 251.586141):
# 1 37 67 79
# Current set of selected variables (score = 225.511446):
# 1 37 67 71 79
# Current set of selected variables (score = 212.007657):
# 1 2 37 67 71 79
# Current set of selected variables (score = 198.745378):
# 1 2 7 37 67 71 79
# Current set of selected variables (score = 186.332050):
# 1 2 7 37 67 71 79 89
# Current set of selected variables (score = 172.630054):
# 1 2 7 31 37 67 71 79 89
# Current set of selected variables (score = 159.530607):
# 1 2 7 19 31 37 67 71 79 89
# Current set of selected variables (score = 145.884724):
# 1 2 7 19 31 37 43 67 71 79 89
# Current set of selected variables (score = 132.733022):
# 1 2 7 19 31 37 43 47 67 71 79 89
# ...

# %%
include("example_multiClass.jl")
# Out:
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# User and numerical derivatives agree
# ...

# %%
# Out:
# 2
