# %%
include("example_RPCA.jl");
# Out:
# (k, d, n) = (5, 4096, 440)
# size(Z[:]) = (2200,)
# Iteration 1, loss = 0.031122
# size(Z[:]) = (2200,)
# Iteration 2, loss = 0.014783
# size(Z[:]) = (2200,)
# Iteration 3, loss = 0.013858
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
include("example_RPCA2.jl");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
include("example_MDS.jl");
# Out:
# Backtracking
#      1     2.08497e-02     2.48445e+03     2.18136e+01
#      2     3.99473e-02     2.33778e+03     1.31905e+01
#      3     4.43590e-02     2.26444e+03     5.68614e+00
#      4     4.45166e-02     2.25375e+03     4.03153e+00
#      5     2.73890e-02     2.25003e+03     2.57681e+00
#      6     2.17230e-02     2.24818e+03     2.80951e+00
#      7     2.55955e-02     2.24705e+03     2.24078e+00
#      8     5.79708e-02     2.24587e+03     2.04854e+00
#      9     9.16657e-02     2.24351e+03     2.43843e+00
#     10     1.21582e-01     2.24093e+03     1.09988e+00
#     11     5.84761e-02     2.23937e+03     1.09767e+00
#     12     2.09240e-02     2.23892e+03     1.12074e+00
#     13     2.01413e-02     2.23851e+03     8.77074e-01
#     14     6.45786e-02     2.23833e+03     8.34531e-01
#     15     1.90988e-01     2.23777e+03     7.94958e-01
#     16     1.43383e-01     2.23647e+03     9.48004e-01
#     17     4.13521e-02     2.23567e+03     9.73951e-01
# ...

# %%
include("example_nnet.jl")
# Out:
# Training iteration = 0
# Training iteration = 1000
# Training iteration = 2000
# Training iteration = 3000
# Training iteration = 4000
# Training iteration = 5000
# Training iteration = 6000
# Training iteration = 7000
# Training iteration = 8000
# Training iteration = 9000
# Training iteration = 10000
# Training iteration = 11000
# Training iteration = 12000
# Training iteration = 13000
# Training iteration = 14000
# Training iteration = 15000
# Training iteration = 16000
# Training iteration = 17000
# Training iteration = 18000
# Training iteration = 19000
# Training iteration = 20000
# Training iteration = 21000
# Training iteration = 22000
# Training iteration = 23000
# Training iteration = 24000
# Training iteration = 25000
# Training iteration = 26000
# Training iteration = 27000
# Training iteration = 28000
# Training iteration = 29000
# Training iteration = 30000
# Training iteration = 31000
# Training iteration = 32000
# Training iteration = 33000
# ...

# %%
include("example_usps.jl")
# Out:
# nHidden = [1000]
# Training iteration = 960, test error = 0.905000
# Training iteration = 1920, test error = 0.889000
# Training iteration = 2880, test error = 0.920000
# Training iteration = 3840, test error = 0.893000
# Training iteration = 4800, test error = 0.861000
# Training iteration = 5760, test error = 0.819000
# Training iteration = 6720, test error = 0.898000
# Training iteration = 7680, test error = 0.866000
# Training iteration = 8640, test error = 0.864000
# Training iteration = 9600, test error = 0.855000
# Training iteration = 10560, test error = 0.876000
# Training iteration = 11520, test error = 0.819000
# Training iteration = 12480, test error = 0.869000
# Training iteration = 13440, test error = 0.835000
# Training iteration = 14400, test error = 0.782000
# Training iteration = 15360, test error = 0.755000
# Training iteration = 16320, test error = 0.808000
# Training iteration = 17280, test error = 0.711000
# Training iteration = 18240, test error = 0.703000
# ...
