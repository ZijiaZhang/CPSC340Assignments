# %%
include("example_nonLinear.jl")
# Out:
# Squared train Error with least squares: 252.017
# Squared test Error with least squares:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 242.791
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x14352df98>

# %%
include("example_nonLinear2.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (Z * Z')[1:1] = [974850.7201206107]
# Squared train Error with least squares: 252.046
# Squared test Error with least squares: 242.805
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x14406a4e0>
