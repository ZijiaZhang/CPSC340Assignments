# %%
include("example_nonLinear.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Squared train Error with least squares: 39.163
# Squared test Error with least squares: 70.580
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x14333eac8>

# %%
include("example_nonLinear2.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (Z * Z')[1:1] = [974850.7201206107]
# Squared train Error with least squares: 252.046
# Squared test Error with least squares: 242.805
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x144a27be0>

# %%
include("example_PCA.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# argmax(W[1, :]) = 13
# argmax(W[2, :]) = 58
# 1 - norm(expand(compress(X)) - X) ^ 2 / norm(X) ^ 2 = 0.30193815155914205
# 1 - norm(model.expand(compressed) - X) ^ 2 / norm(X) ^ 2 = 0.30193815155914205

# %%
dataTable[1,14]
# Out:
# "hairless"

# %%
dataTable[1,59]
# Out:
# "grazer"
